# %%
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
root_agent = Agent(
    name="Personal_Doctor",
    model="gemini-1.5-flash",
    description="An AI agent that provides personalized health advice and information.",
    instruction="You are a knowledgeable and empathetic personal doctor. ",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "D:\Google Course\myenv\Lib\site-packages\google\adk\agents", which implies app name "agents".
# ✅ Runner created.

# %%
response = await runner.run_debug("I am stuck in alopecia areata, what should I do? it is in my chin area?")
# Out:
#  ### Continue session: debug_session_id
#
# User > I am stuck in alopecia areata, what should I do? it is in my chin area?
# Personal_Doctor > I understand you're going through a challenging time dealing with alopecia areata on your chin. It can be distressing to experience hair loss, especially in a noticeable area. Alopecia areata is an autoimmune condition where your immune system mistakenly attacks your hair follicles, leading to hair loss in patches. While there's no cure, various treatments can help stimulate hair regrowth.
#
# Here's what you should do:
#
# 1.  **Consult a Dermatologist:** This is the most crucial first step. A board-certified dermatologist can accurately diagnose your condition, rule out other causes of hair loss, and recommend the most appropriate treatment plan for you. They can examine the affected area, and sometimes perform a biopsy or blood tests to check for underlying conditions like thyroid disease.
#
# 2.  **Understand Treatment Options:** Treatment for alopecia areata depends on several factors, including the extent and duration of hair loss, its location, and your age. For patchy hair loss like yours, especially on the face, common treatments include:
#     *   **Corticosteroid Injections:** These are often a first-line treatment for adults with patchy alopecia areata. A dermatologist injects corticosteroids directly into the bald spots to reduce inflammation around the hair follicles and promote regrowth. Many find this effective, with new hair growth potentially appearing within six to eight weeks.
#     *   **Topical Corticosteroids:** These medications are applied directly to the bald patches, usually once or twice a day, to help reduce inflammation and stimulate hair growth. They are sometimes combined with other treatments.
#     *   **Minoxidil:** This medication can help maintain regrown hair after other treatments, and can be helpful for the beard area.
#     *   **JAK Inhibitors:** These are newer oral medications that calm the overactive immune system. They are approved for more severe cases of alopecia areata and can be very effective in promoting regrowth, including in areas like eyebrows and eyelashes.
#
# 3.  **Be Patient and Consistent:** Hair regrowth can be slow, and finding the right treatment may take some time and patience. It's important to follow your dermatologist's recommendations diligently.
#
# 4.  **Emotional Support:** Living with alopecia areata can impact your self-confidence and may cause stress or anxiety. It's helpful to remember that you're not alone. Consider joining a patient support group to connect with others who understand what you're going through. They can also offer practical tips for managing the condition.
#
# While there is currently no cure for alopecia areata, many people experience hair regrowth with treatment, and in some cases, hair can even grow back on its own. Your dermatologist can provide personalized advice and help you navigate your options.
